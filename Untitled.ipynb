# %% [markdown]
# # Zomato Recommendation System

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")

# %%
pwd
# Out:
# 'C:\\Users\\HP\\Documents\\DS-ML-IOT\\mini project\\Recommendation system'

# %%
df= pd.read_csv('zomato.csv')
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                             phone  \
# 0            Yes   4.1/5    775    080 42297555\r\n+91 9743772233
# 1             No   4.1/5    787                      080 41714161
# 2             No   3.8/5    918                    +91 9663487993
# 3             No   3.7/5     88                    +91 9620009302
# 4             No   3.8/5    166  +91 8026612447\r\n+91 9901210005
# ...          ...     ...    ...                               ...
# 51712         No  3.6 /5     27                      080 40301477
# 51713         No     NaN      0                    +91 8197675843
# 51714         No     NaN      0                               NaN
# 51715        Yes  4.3 /5    236                      080 49652769
# 51716         No  3.4 /5     13                    +91 8071117272
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 51712                  Whitefield                  Bar
# 51713                  Whitefield                  Bar
# 51714                  Whitefield                  Bar
# 51715  ITPL Main Road, Whitefield                  Bar
# 51716  ITPL Main Road, Whitefield   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                NaN
# 51713                                                NaN
# 51714                                                NaN
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                NaN
#
#                                      cuisines approx_cost(for two people)  \
# 0              North Indian, Mughlai, Chinese                         800
# 1                 Chinese, North Indian, Thai                         800
# 2                      Cafe, Mexican, Italian                         800
# 3                  South Indian, North Indian                         300
# 4                    North Indian, Rajasthani                         600
# ...                                       ...                         ...
# 51712                             Continental                       1,500
# 51713                             Finger Food                         600
# 51714                             Finger Food                       2,000
# 51715                             Finger Food                       2,500
# 51716  Finger Food, North Indian, Continental                       1,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51713                                                 []        []
# 51714                                                 []        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51712   Pubs and bars      Whitefield
# 51713   Pubs and bars      Whitefield
# 51714   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [51717 rows x 17 columns]

# %%
rows_to_extract = 51717 // 2  # Replace this with the desired number of rows

# Extract the specified number of rows from the beginning
df = df.iloc[:rows_to_extract, :]

# Display the extracted data
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 25853  https://www.zomato.com/bangalore/lassi-house-b...
# 25854  https://www.zomato.com/bangalore/cafeteria-al-...
# 25855  https://www.zomato.com/bangalore/grow-fit-bana...
# 25856  https://www.zomato.com/bangalore/multi-ruchish...
# 25857  https://www.zomato.com/bangalore/m-k-lassi-fra...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 25853  Shop 339, Ombr Layout, 4TH Main Road Next To C...
# 25854  1, MKV Building, 4th Cross, OMBR Layout, 60 Fe...
# 25855  21/1, First Cross, Bhaskar Reddy Building, Lak...
# 25856  48, 2nd Cross, Jananeshwari Layout, Thindlu, V...
# 25857  Bilal Masjid Complex, Pillana Garden, 3rd Stag...
#
#                         name online_order book_table   rate  votes  \
# 0                      Jalsa          Yes        Yes  4.1/5    775
# 1             Spice Elephant          Yes         No  4.1/5    787
# 2            San Churro Cafe          Yes         No  3.8/5    918
# 3      Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4              Grand Village           No         No  3.8/5    166
# ...                      ...          ...        ...    ...    ...
# 25853            Lassi House           No         No    NEW      0
# 25854   Cafeteria Al - Falah           No         No  3.3/5      5
# 25855               Grow Fit           No         No  3.8/5     68
# 25856          Multi Ruchish          Yes         No    NEW      0
# 25857              M K Lassi           No         No    NaN      0
#
#                                   phone      location            rest_type  \
# 0        080 42297555\r\n+91 9743772233  Banashankari        Casual Dining
# 1                          080 41714161  Banashankari        Casual Dining
# 2                        +91 9663487993  Banashankari  Cafe, Casual Dining
# 3                        +91 9620009302  Banashankari          Quick Bites
# 4      +91 8026612447\r\n+91 9901210005  Basavanagudi        Casual Dining
# ...                                 ...           ...                  ...
# 25853                    +91 9008540141     Banaswadi        Beverage Shop
# 25854  +91 8951359153\r\n+91 7349377279     Banaswadi          Quick Bites
# 25855  +91 9066617285\r\n+91 7795003095     Banaswadi             Delivery
# 25856                    +91 7259722683  New BEL Road          Quick Bites
# 25857                               NaN   Frazer Town        Beverage Shop
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 25853                                                NaN
# 25854                                                NaN
# 25855                                                NaN
# 25856                                                NaN
# 25857                                                NaN
#
#                                   cuisines approx_cost(for two people)  \
# 0           North Indian, Mughlai, Chinese                         800
# 1              Chinese, North Indian, Thai                         800
# 2                   Cafe, Mexican, Italian                         800
# 3               South Indian, North Indian                         300
# 4                 North Indian, Rajasthani                         600
# ...                                    ...                         ...
# 25853                  Beverages, Desserts                         150
# 25854              Fast Food, North Indian                         300
# 25855     Healthy Food, North Indian, Thai                         500
# 25856  North Indian, South Indian, Chinese                         250
# 25857                            Beverages                         100
#
#                                             reviews_list  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...
# 3      [('Rated 4.0', "RATED\n  Great food and proper...
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...
# ...                                                  ...
# 25853                                                 []
# 25854                                                 []
# 25855  [('Rated 4.0', 'RATED\n  I ordered using swigg...
# 25856                                                 []
# 25857                                                 []
#
#                                                menu_item listed_in(type)  \
# 0                                                     []          Buffet
# 1                                                     []          Buffet
# 2                                                     []          Buffet
# 3                                                     []          Buffet
# 4                                                     []          Buffet
# ...                                                  ...             ...
# 25853                                                 []        Delivery
# 25854                                                 []        Delivery
# 25855                                                 []        Delivery
# 25856  ['Mughlai Biryani', 'Multi Special Chicken Bir...        Delivery
# 25857                                                 []        Delivery
#
#       listed_in(city)
# 0        Banashankari
# 1        Banashankari
# 2        Banashankari
# 3        Banashankari
# 4        Banashankari
# ...               ...
# 25853    Kammanahalli
# 25854    Kammanahalli
# 25855    Kammanahalli
# 25856    Kammanahalli
# 25857    Kammanahalli
#
# [25858 rows x 17 columns]

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25858 entries, 0 to 25857
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          25858 non-null  object
#  1   address                      25858 non-null  object
#  2   name                         25858 non-null  object
#  3   online_order                 25858 non-null  object
#  4   book_table                   25858 non-null  object
#  5   rate                         21986 non-null  object
#  6   votes                        25858 non-null  int64
#  7   phone                        25341 non-null  object
#  8   location                     25854 non-null  object
#  9   rest_type                    25744 non-null  object
#  10  dish_liked                   11477 non-null  object
#  11  cuisines                     25840 non-null  object
#  12  approx_cost(for two people)  25763 non-null  object
#  13  reviews_list                 25858 non-null  object
#  14  menu_item                    25858 non-null  object
#  15  listed_in(type)              25858 non-null  object
#  16  listed_in(city)              25858 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 3.4+ MB

# %%
df=df.drop(['url','dish_liked','phone'],axis=1)

# %%
df.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes      location            rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari        Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari        Casual Dining
# 2          Yes         No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5     88  Banashankari          Quick Bites
# 4           No         No  3.8/5    166  Basavanagudi        Casual Dining
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(how='any',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21832 entries, 0 to 25856
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      21832 non-null  object
#  1   name                         21832 non-null  object
#  2   online_order                 21832 non-null  object
#  3   book_table                   21832 non-null  object
#  4   rate                         21832 non-null  object
#  5   votes                        21832 non-null  int64
#  6   location                     21832 non-null  object
#  7   rest_type                    21832 non-null  object
#  8   cuisines                     21832 non-null  object
#  9   approx_cost(for two people)  21832 non-null  object
#  10  reviews_list                 21832 non-null  object
#  11  menu_item                    21832 non-null  object
#  12  listed_in(type)              21832 non-null  object
#  13  listed_in(city)              21832 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 2.5+ MB

# %%
df = df.rename(columns={'approx_cost(for two people)':'cost','listed_in(type)':'type',
                                  'listed_in(city)':'city'})

# %%
df.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5'], dtype=object)

# %%
df= df.loc[df.rate !='NEW']
df = df.loc[df.rate !='-'].reset_index(drop=True)
remove_slash = lambda x: x.replace('/5', '') if type(x) == np.str else x
df.rate = df.rate.apply(remove_slash).str.strip().astype('float')
df['rate'].head()
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: float64

# %%
df.name = df.name.apply(lambda x:x.title())
df.online_order.replace(('Yes','No'),(True, False),inplace=True)
df.book_table.replace(('Yes','No'),(True, False),inplace=True)
df.cost.unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '1,100', '1,600', '230',
#        '130', '1,700', '1,350', '2,200', '1,400', '2,000', '1,800',
#        '1,900', '180', '330', '2,500', '2,100', '3,000', '2,800', '3,400',
#        '50', '40', '1,250', '3,500', '4,000', '2,400', '2,600', '1,450',
#        '70', '3,200', '240', '6,000', '1,050'], dtype=object)

# %%
df['cost'] = df['cost'].astype(str) #Changing the cost to string
df['cost'] = df['cost'].apply(lambda x: x.replace(',','.')) #Using lambda function to replace ',' from cost
df['cost'] = df['cost'].astype(float) # Changing the cost to Float
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20416 entries, 0 to 20415
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       20416 non-null  object
#  1   name          20416 non-null  object
#  2   online_order  20416 non-null  bool
#  3   book_table    20416 non-null  bool
#  4   rate          20416 non-null  float64
#  5   votes         20416 non-null  int64
#  6   location      20416 non-null  object
#  7   rest_type     20416 non-null  object
#  8   cuisines      20416 non-null  object
#  9   cost          20416 non-null  float64
#  10  reviews_list  20416 non-null  object
#  11  menu_item     20416 non-null  object
#  12  type          20416 non-null  object
#  13  city          20416 non-null  object
# dtypes: bool(2), float64(2), int64(1), object(9)
# memory usage: 1.9+ MB

# %%
restaurants = list(df['name'].unique())
df['Mean Rating'] = 0

for i in range(len(restaurants)):
    df['Mean Rating'][df['name'] == restaurants[i]] = df['rate'][df['name'] == restaurants[i]].mean()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (1,5))

df[['Mean Rating']] = scaler.fit_transform(df[['Mean Rating']]).round(2)

df.sample(3)
# Out:
#                                                  address  \
# 266    241, 4th Floor, 100 Feet Ring Road, Opposite K...
# 14916  G 2, 28/A, Smart Avenue, 80 Feet road, Indiran...
# 6257   Opposite Silver Line Bakery, Kundanahalli Gate...
#
#                                    name  online_order  book_table  rate  \
# 266                        Catch-Up-Ino          True       False   3.9
# 14916                          Yomama!!          True        True   4.0
# 6257   M.M.A. Kabab'S & Biriyani Center          True       False   3.2
#
#        votes      location    rest_type  \
# 266      133  Banashankari         Cafe
# 14916    340   Indiranagar  Quick Bites
# 6257     789   Brookefield  Quick Bites
#
#                                            cuisines   cost  \
# 266    Cafe, Fast Food, Continental, Chinese, Momos  800.0
# 14916              Continental, Burger, Cafe, Steak  800.0
# 6257    Arabian, Mughlai, Chinese, Kebab, Fast Food  400.0
#
#                                             reviews_list  \
# 266    [('Rated 1.0', "RATED\n  This place is right o...
# 14916  [('Rated 4.0', "RATED\n  Good food and good se...
# 6257   [('Rated 5.0', "RATED\n  It's nice place for n...
#
#                                                menu_item      type  \
# 266                                                   []  Delivery
# 14916  ['Yomama Special Chicken Steak Garlic Sauce', ...  Dine-out
# 6257   ['Chicken Seekh Kabab [6 Pieces]', 'Al Faham',...  Dine-out
#
#                city  Mean Rating
# 266    Banashankari         3.71
# 14916   Indiranagar         3.43
# 6257    Brookefield         2.81

# %%
df["reviews_list"] = df["reviews_list"].str.lower()
df[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                             reviews_list  \
# 2964   [('rated 5.0', 'rated\n  newly opened cafe nea...
# 12980  [('rated 3.0', "rated\n  new small segmented r...
# 6880   [('rated 3.0', "rated\n  a good and quiet plac...
# 16644  [('rated 4.0', "rated\n  just came back home. ...
# 11219  [('rated 4.0', 'rated\n  i usually order here....
#
#                                          cuisines
# 2964                   Cafe, Fast Food, Beverages
# 12980        North Indian, Fast Food, Street Food
# 6880   Cafe, North Indian, Pizza, Sandwich, Salad
# 16644                              Cafe, Desserts
# 11219         Biryani, South Indian, North Indian

# %%
import string
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df["reviews_list"] = df["reviews_list"].apply(lambda text: remove_punctuation(text))
df[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                             reviews_list  \
# 361    rated 30 ratedn  couple of nights ago i had th...
# 9657   rated 30 ratedn  a small space with a cozy amb...
# 17876  rated 50 ratedn  tried muddhe and soppa saaru ...
# 18595  rated 50 ratedn  tasty pocket friendly restaur...
# 6358   rated 40 ratedn  being just a few steps away f...
#
#                                                cuisines
# 361                                      Tibetan, Momos
# 9657   Cafe, Mediterranean, Italian, Pizza, Continental
# 17876                             South Indian, Biryani
# 18595                             North Indian, Chinese
# 6358                                 Continental, Asian

# %%
import re
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)


df["reviews_list"] = df["reviews_list"].apply(lambda text: remove_urls(text))

# %%
df[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                             reviews_list  \
# 11794  rated 30 ratedn  a very lovely and quiet resta...
# 20136  rated 10 ratedn  they delivered dead ants in g...
# 14911
# 9184   rated 40 ratedn  best buffet in bangalore hand...
# 12788  rated 40 ratedn  they serve delicious south in...
#
#                                         cuisines
# 11794  Cafe, Italian, Pizza, Beverages, Desserts
# 20136             North Indian, Mughlai, Biryani
# 14911         Juices, Fast Food, Desserts, Salad
# 9184        European, Continental, Chinese, Thai
# 12788                    Chettinad, South Indian

# %%
df=df.drop(['address','rest_type', 'type', 'menu_item', 'votes'],axis=1)

# %%
df.head()
# Out:
#                     name  online_order  book_table  rate      location  \
# 0                  Jalsa          True        True   4.1  Banashankari
# 1         Spice Elephant          True       False   4.1  Banashankari
# 2        San Churro Cafe          True       False   3.8  Banashankari
# 3  Addhuri Udupi Bhojana         False       False   3.7  Banashankari
# 4          Grand Village         False       False   3.8  Basavanagudi
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
# 3      South Indian, North Indian  300.0
# 4        North Indian, Rajasthani  600.0
#
#                                         reviews_list          city  \
# 0  rated 40 ratedn  a beautiful place to dine int...  Banashankari
# 1  rated 40 ratedn  had been here for dinner with...  Banashankari
# 2  rated 30 ratedn  ambience is not that good eno...  Banashankari
# 3  rated 40 ratedn  great food and proper karnata...  Banashankari
# 4  rated 40 ratedn  very good restaurant in neigh...  Banashankari
#
#    Mean Rating
# 0         3.98
# 1         3.97
# 2         3.58
# 3         3.45
# 4         3.58

# %%
import pandas

# Randomly sample 60% of your dataframe
df_percent = df.sample(frac=0.5)

# %%
df_percent.shape
# Out:
# (10208, 10)

# %%
df_percent.set_index('name', inplace=True)

# %%
indices = pd.Series(df_percent.index)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_percent['reviews_list'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Assuming tfidf_matrix is a sparse matrix
cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix

# Convert dense tfidf_matrix to sparse format
sparse_tfidf_matrix = csr_matrix(tfidf_matrix)

# Calculate cosine similarities using cosine_similarity
cosine_similarities = cosine_similarity(sparse_tfidf_matrix, sparse_tfidf_matrix)

# %%
def recommend(name, cosine_similarities = cosine_similarities):
    
    # Create a list to put top restaurants
    recommend_restaurant = []
    
    # Find the index of the hotel entered
    idx = indices[indices == name].index[0]
    
    # Find the restaurants with a similar cosine-sim value and order them from bigges number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
    
    # Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_percent.index)[each])
    
    # Creating the new data set to show similar restaurants
    df_new = pd.DataFrame(columns=['cuisines', 'Mean Rating', 'cost'])
    
    # Create the top 30 similar restaurants with some of their columns
    for each in recommend_restaurant:
        df_new = df_new.append(pd.DataFrame(df_percent[['cuisines','Mean Rating', 'cost']][df_percent.index == each].sample()))
    
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    df_new = df_new.drop_duplicates(subset=['cuisines','Mean Rating', 'cost'], keep=False)
    
    df_new = df_new.sort_values(by='Mean Rating', ascending=False).head(10)
    
    print('TOP %s RESTAURANTS LIKE %s WITH SIMILAR REVIEWS: ' % (str(len(df_new)), name))
    
    return df_new

# %%
recommend('Pai Vihar')
# Out:
# TOP 5 RESTAURANTS LIKE Pai Vihar WITH SIMILAR REVIEWS:
#                                                   cuisines  Mean Rating   cost
# Samosa Singh                          North Indian, Mithai         3.59  250.0
# Shanthi Sagar          South Indian, North Indian, Chinese         3.48  400.0
# Shanthi Sagar  South Indian, North Indian, Chinese, Juices         3.48  250.0
# Udupi Grand            South Indian, North Indian, Chinese         3.27  300.0
# Udupi Grand            South Indian, North Indian, Chinese         3.27  450.0

# %%
recommend('Jalsa')
# Out:
# TOP 10 RESTAURANTS LIKE Jalsa WITH SIMILAR REVIEWS:
#                                                                                     cuisines  \
# Biergarten                                        Continental, European, BBQ, Chinese, Asian
# Jalsa Gold                                                    North Indian, Mughlai, Italian
# Bombay Adda                                                                    Modern Indian
# Foxtrot                                            North Indian, Chinese, Continental, Momos
# CafãÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Felix                        American, Cafe, Continental
# The Rig                                                      Continental, Finger Food, Pizza
# Church Street Social                       American, North Indian, Chinese, Finger Food, ...
# Lazy Suzy                                  Cafe, Continental, Beverages, Burger, Desserts...
# Hoot                                                      Continental, Italian, North Indian
# Cream Stone                                                              Desserts, Beverages
#
#                                            Mean Rating   cost
# Biergarten                                        4.74    2.4
# Jalsa Gold                                        4.48    1.3
# Bombay Adda                                       4.48    1.1
# Foxtrot                                           4.35    1.2
# CafãÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Felix         4.35    1.7
# The Rig                                           4.23    1.5
# Church Street Social                              4.23    1.5
# Lazy Suzy                                         4.23    1.0
# Hoot                                              4.10    1.4
# Cream Stone                                       3.99  500.0
